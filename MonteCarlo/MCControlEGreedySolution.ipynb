# %%
import matplotlib
import gym
import sys
if "../" not in sys.path:
    sys.path.append("../") 
from lib import plotting
from MCControlEGreedySolution import basic_policy
from MCControlEGreedySolution import first_visit_mc_prediction
from MCControlEGreedySolution import update_V
from MCControlEGreedySolution import mc_control_epsilon_greedy
#from MCControlEGreedySolution import update_V
from MCControlEGreedySolution import QtoVP

# %%
env_name = 'Blackjack-v0'
env = gym.make(env_name)

matplotlib.style.use('ggplot')

# %%
Q, policy = mc_control_epsilon_greedy(env, num_episodes=100000, epsilon=0.2)
V,P = QtoVP(Q)
plotting.plot_value_function(V, title="Optimal Value Function - 100k, 0.2")
plotting.plot_value_function(P, title="Optimal Policy - 100k, 0.2")
# Out:
# Episode 100000/100000.

# %%
Q, policy = mc_control_epsilon_greedy(env, num_episodes=100000, epsilon=0.3)
V,P = QtoVP(Q)
plotting.plot_value_function(V, title="Optimal Value Function - 100k, 0.3")
plotting.plot_value_function(P, title="Optimal Policy - 100k, 0.3")
# Out:
# Episode 100000/100000.

# %%
Q, policy = mc_control_epsilon_greedy(env, num_episodes=100000, epsilon=0.4)
V,P = QtoVP(Q)
plotting.plot_value_function(V, title="Optimal Value Function - 100k, 0.4") 
plotting.plot_value_function(P, title="Optimal Policy - 100k, 0.4")
# Out:
# Episode 100000/100000.

# %%
Q, policy = mc_control_epsilon_greedy(env, num_episodes=1000000, epsilon=0.2)
V,P = QtoVP(Q)
plotting.plot_value_function(V, title="Optimal Value Function - 1m, 0.2")
plotting.plot_value_function(P, title="Optimal Policy - 1m, 0.2")
# Out:
# Episode 1000000/1000000.

# %%
Q, policy = mc_control_epsilon_greedy(env, num_episodes=10000000, epsilon=0.2)
V,P = QtoVP(Q)
plotting.plot_value_function(V, title="Optimal Value Function - 10m, 0.2")
plotting.plot_value_function(P, title="Optimal Policy - 10m, 0.2")
# Out:
# Episode 10000000/10000000.
