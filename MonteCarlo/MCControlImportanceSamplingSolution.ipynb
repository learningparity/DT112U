# %%
import matplotlib
import gym
import sys
if "../" not in sys.path:
    sys.path.append("../") 
from lib import plotting

from MCControlImportanceSamplingSolution import mc_control_importance_sampling
from MCControlImportanceSamplingSolution import QtoVP

# %%
env_name = 'Blackjack-v0'
env = gym.make(env_name)

matplotlib.style.use('ggplot')

# %%
Q, policy = mc_control_importance_sampling(env, num_episodes=100000, discount_factor=1.0)
V,P = QtoVP(Q)
plotting.plot_value_function(V, title="Optimal Value Function - 100k")
plotting.plot_value_function(P, title="Optimal Policy - 100k")
# Out:
# Episode 100000/100000.

# %%
Q, policy = mc_control_importance_sampling(env, num_episodes=500000, discount_factor=1.0)
V,P = QtoVP(Q)
plotting.plot_value_function(V, title="Optimal Value Function - 500k")
plotting.plot_value_function(P, title="Optimal Policy - 500k")
# Out:
# Episode 500000/500000.

# %%
Q, policy = mc_control_importance_sampling(env, num_episodes=1000000, discount_factor=1.0)
V,P = QtoVP(Q)
plotting.plot_value_function(V, title="Optimal Value Function - 1m")
plotting.plot_value_function(P, title="Optimal Policy - 1m")
# Out:
# Episode 1000000/1000000.

# %%
Q, policy = mc_control_importance_sampling(env, num_episodes=10000000, discount_factor=1.0)
V,P = QtoVP(Q)
plotting.plot_value_function(V, title="Optimal Value Function - 10m")
plotting.plot_value_function(P, title="Optimal Policy - 10m")
# Out:
# Episode 10000000/10000000.
