# %%
import matplotlib
import gym
import sys
if "../" not in sys.path:
    sys.path.append("../") 
from lib import plotting
from MC_Prediction_Solution import basic_policy
from MC_Prediction_Solution import first_visit_mc_prediction
from MC_Prediction_Solution import update_V_DB
from MC_Prediction_Solution import update_V_AA

# %%
env_name = 'Blackjack-v0'
env = gym.make(env_name)

matplotlib.style.use('ggplot')

# %%
V_10k = first_visit_mc_prediction(basic_policy, env, num_episodes=10000, update_V=update_V_AA)
plotting.plot_value_function(V_10k, title="AA 10,000 Steps")
# Out:
# Episode 10000/10000.

# %%
V_10k = first_visit_mc_prediction(basic_policy, env, num_episodes=10000, update_V=update_V_DB)
plotting.plot_value_function(V_10k, title="DB 10,000 Steps")
# Out:
# Episode 10000/10000.

# %%
V_500k = first_visit_mc_prediction(basic_policy, env, num_episodes=500000)
plotting.plot_value_function(V_500k, title="500,000 Steps")
# Out:
# Episode 500000/500000.
